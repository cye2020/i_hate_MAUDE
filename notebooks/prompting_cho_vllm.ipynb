# %% [markdown]
# # mdr_text 프롬프팅 과정 (vLLM 버전)

# %%
from typing import (
    Tuple,
    List,
    Dict,
    Any,
    Sequence,
    Union,
    Optional,
)

import sys
import time
import json
import re
from pathlib import Path
from enum import Enum
import shutil

import pandas as pd
import polars as pl
import polars.selectors as cs
import psutil

from tqdm import tqdm, trange
from pprint import pprint, pformat

# pydantic
from pydantic import BaseModel, Field, field_validator

# vLLM
from vllm import LLM, SamplingParams
from transformers import AutoTokenizer
from vllm.sampling_params import StructuredOutputsParams

# 상대 경로 사용
PROJECT_ROOT = Path.cwd().parent
DATA_DIR = PROJECT_ROOT / 'data'

# 로컬 모듈
# 맨 앞에 추가
if str(PROJECT_ROOT) in sys.path:
    sys.path.remove(str(PROJECT_ROOT))
sys.path.insert(0, str(PROJECT_ROOT))
from src.preprocess.preprocess import overview_col, analyze_null_values, eda_proportion

# %%
import sys
from pathlib import Path
import glob

# 상대 경로 사용
PROJECT_ROOT = Path.cwd().parent
DATA_DIR = PROJECT_ROOT / 'data'

# 맨 앞에 추가
sys.path.insert(0, str(PROJECT_ROOT))

# 이제 import
from src.loading import DataLoader
from src.utils import increment_path

output_dir = DATA_DIR / 'silver'
output_files = sorted(output_dir.glob('maude_part*.parquet'))
output_files = output_dir / 'maude_74071_2025-12-23.parquet'
maude_lf = pl.scan_parquet(output_files)
# output_path = DATA_DIR / 'silver' / 'maude_part*.parquet'
# loader = DataLoader(
#     # output_file= DATA_DIR / 'silver' / 'maude50.parquet',
#     output_file= output_files,
# )

# %%
# 저장
# maude_lf.sink_parquet(
#         DATA_DIR / 'gold' / 'maude.parquet',
#     compression='zstd',
#     compression_level=3,
#     maintain_order=True
# )

# %%
# adapter = 'polars'
# polars_kwargs = {
#     'use_statistics': True,
#     'parallel': 'auto',
#     'low_memory': False,
#     'rechunk': False,
#     'cache': True,
# }
# maude_lf = loader.load(adapter=adapter, **polars_kwargs)
# maude_lf

# %%
total_cols = maude_lf.collect_schema().names()
analyze_null_values(maude_lf, total_cols)
# Out:
# === 결측치 분석 ===
# 전체 행 수: 74,071
#
# outcome_L                                    :     24,820개 ( 33.51%)
# outcome_H                                    :     24,820개 ( 33.51%)
# outcome_S                                    :     24,820개 ( 33.51%)
# outcome_C                                    :     24,820개 ( 33.51%)
# outcome_R                                    :     24,820개 ( 33.51%)
# outcome_D                                    :     24,820개 ( 33.51%)
# outcome_O                                    :     24,820개 ( 33.51%)
# patient_age                                  :     16,727개 ( 22.58%)
# previous_use_flag                            :      2,046개 (  2.76%)
# single_use_flag                              :      1,577개 (  2.13%)
# operator                                     :      1,295개 (  1.75%)
# reprocessed_and_reused_flag                  :        800개 (  1.08%)
# brand_name                                   :        392개 (  0.53%)
# mdr_report_key                               :          0개 (  0.00%)
# adverse_event_flag                           :          0개 (  0.00%)
# product_problem_flag                         :          0개 (  0.00%)
# date_occurred                                :          0개 (  0.00%)
# date_received                                :          0개 (  0.00%)
# date_manufactured                            :          0개 (  0.00%)
# event_type                                   :          0개 (  0.00%)
# product_problems                             :          0개 (  0.00%)
# manufacturer_name                            :          0개 (  0.00%)
# model_number                                 :          0개 (  0.00%)
# udi_di                                       :          0개 (  0.00%)
# product_code                                 :          0개 (  0.00%)
# product_name                                 :          0개 (  0.00%)
# mdr_text                                     :          0개 (  0.00%)
# patient_harm                                 :          1개 (  0.00%)
# problem_components                           :          1개 (  0.00%)
# defect_confirmed                             :          1개 (  0.00%)
# defect_type                                  :          1개 (  0.00%)
# shape: (31, 3)
# ┌────────────────────┬────────────┬──────────┐
# │ column             ┆ null_count ┆ null_pct │
# │ ---                ┆ ---        ┆ ---      │
# │ str                ┆ u32        ┆ f64      │
# ╞════════════════════╪════════════╪══════════╡
# │ outcome_L          ┆ 24820      ┆ 33.51    │
# │ outcome_H          ┆ 24820      ┆ 33.51    │
# │ outcome_S          ┆ 24820      ┆ 33.51    │
# │ outcome_C          ┆ 24820      ┆ 33.51    │
# │ outcome_R          ┆ 24820      ┆ 33.51    │
# │ …                  ┆ …          ┆ …        │
# │ mdr_text           ┆ 0          ┆ 0.0      │
# │ patient_harm       ┆ 1          ┆ 0.0      │
# │ problem_components ┆ 1          ┆ 0.0      │
# │ defect_confirmed   ┆ 1          ┆ 0.0      │
# │ defect_type        ┆ 1          ┆ 0.0      │
# └────────────────────┴────────────┴──────────┘

# %%
import polars as pl

# 중복된 행의 총 개수 계산 (Lazy)
duplicate_count_query = (
    maude_lf
    .filter(pl.struct(total_cols).is_duplicated()) # 모든 컬럼 기준 중복 필터
    .select(pl.len()) # 행 개수 세기
)

# 결과 확인
print(duplicate_count_query.collect())
# Out:
# shape: (1, 1)
# ┌─────┐
# │ len │
# │ --- │
# │ u32 │
# ╞═════╡
# │ 0   │
# └─────┘

# %%
# other_lf = maude_lf.filter(
#     pl.col('defect_type').eq('Other')
# ).select(
#     pl.all().sample(
#         fraction=0.1,
#         with_replacement=False,
#         shuffle=True,
#         seed=4242
#     )
# )

# other_df = other_lf.collect().to_pandas()
# other_df.to_csv('other_sample.csv', index=False)

# %%
maude_list_lf = maude_lf.with_columns(
    pl.col('product_problems')
    .str.replace_all("'", '"')
    .str.json_decode(dtype=pl.List(pl.String)).alias('product_problems')
)

# maude_lf.collect()

# %%
maude_list_lf.filter(
    pl.col('defect_type').is_in(['Other', 'Unknown']),
    pl.col('product_problems').list.set_intersection(['Adverse Event Without Identified Device or Use Problem', 'No Apparent Adverse Event']).list.len()==0
).select(
    [
        'product_problems', 'mdr_text', 
        # 'defect_type_original_text'
    ]
).collect().to_pandas()
# Out:
#                                         product_problems  \
# 0                  [Device Appears to Trigger Rejection]
# 1                  [Device Appears to Trigger Rejection]
# 2                  [Device Appears to Trigger Rejection]
# 3                             [Insufficient Information]
# 4      [Detachment of Device or Device Component, Ins...
# ...                                                  ...
# 66424                   [Unexpected Therapeutic Results]
# 66425                         [Insufficient Information]
# 66426                         [Insufficient Information]
# 66427                                         [Degraded]
# 66428              [Device Appears to Trigger Rejection]
#
#                                                 mdr_text
# 0      [Additional Manufacturer Narrative]\na review ...
# 1      [Additional Manufacturer Narrative]\na review ...
# 2      [Additional Manufacturer Narrative]\na review ...
# 3      [Additional Manufacturer Narrative]\nthe devic...
# 4      [Description of Event or Problem]\nit was lear...
# ...                                                  ...
# 66424  [Description of Event or Problem]\nit was repo...
# 66425  [Description of Event or Problem]\nit was repo...
# 66426  [Description of Event or Problem]\nit was repo...
# 66427  [Additional Manufacturer Narrative]\nper the i...
# 66428  [Description of Event or Problem]\npatient rep...
#
# [66429 rows x 2 columns]

# %%
failure_maude_lf = maude_lf.with_columns(
    pl.col('product_problems')
    .str.replace_all("'", '"')
    .str.json_decode(dtype=pl.List(pl.String)).alias('product_problems_list')
).filter(
    pl.col('defect_type').is_in(['Other', 'Unknown']),
    pl.col('product_problems_list').list.set_intersection(['Adverse Event Without Identified Device or Use Problem', 'No Apparent Adverse Event']).list.len().eq(0)
).drop(['product_problems_list', "patient_harm", "problem_components", "defect_confirmed", "defect_type"])

failure_path = DATA_DIR / 'temp' / 'maude_failure.parquet'
failure_maude_lf.sink_parquet(
    path=failure_path,
    compression='zstd',
    compression_level=3,
    maintain_order=True
)

# %%
array = maude_lf.filter(
    pl.col('defect_type').eq('Other')
).select(pl.col('product_problems')).collect().to_series().explode().unique().to_numpy()

array
# Out:
# array(["['Calcified', 'Degraded', 'Device Stenosis']",
#        "['Fracture', 'High impedance', 'Defective Device', 'High Capture Threshold']",
#        "['Misconnection', 'Device Difficult to Setup or Prepare']", ...,
#        "['Break', 'Failure to Advance']",
#        "['Positioning Failure', 'Material Deformation', 'Activation Failure']",
#        "['Break', 'Physical Resistance/Sticking']"],
#       shape=(2336,), dtype=object)

# %%
maude_lf.select(['product_problem_flag', 'defect_confirmed']).collect().to_pandas().value_counts(normalize=True).mul(100).round(1)
# Out:
# product_problem_flag  defect_confirmed
# True                  False               62.3
# False                 False               29.9
# True                  True                 6.0
# False                 True                 1.8
# Name: proportion, dtype: float64

# %%
maude_lf.filter(
    pl.col('product_problem_flag').xor(pl.col('defect_confirmed'))
).select(pl.col(['mdr_text', 'product_problem_flag', 'defect_confirmed', 'product_problems', 'defect_type'])).collect().to_pandas()
# Out:
#                                                 mdr_text  \
# 0      [Additional Manufacturer Narrative]\nthe lens ...
# 1      [Additional Manufacturer Narrative]\nif inform...
# 2      [Additional Manufacturer Narrative]\napproxima...
# 3      [Additional Manufacturer Narrative]\na sample ...
# 4      [Additional Manufacturer Narrative]\nif inform...
# ...                                                  ...
# 47501  [Description of Event or Problem]\nit was repo...
# 47502  [Description of Event or Problem]\nit was repo...
# 47503  [Description of Event or Problem]\nit was repo...
# 47504  [Additional Manufacturer Narrative]\nper the i...
# 47505  [Description of Event or Problem]\npatient rep...
#
#        product_problem_flag  defect_confirmed  \
# 0                      True             False
# 1                      True             False
# 2                      True             False
# 3                      True             False
# 4                      True             False
# ...                     ...               ...
# 47501                  True             False
# 47502                  True             False
# 47503                  True             False
# 47504                  True             False
# 47505                  True             False
#
#                                         product_problems defect_type
# 0                ['Appropriate Term/Code Not Available']     Unknown
# 1      ['Over-Sensing', 'Inappropriate/Inadequate Sho...     Unknown
# 2                     ['Unexpected Therapeutic Results']     Unknown
# 3                                 ['Scratched Material']       Other
# 4      ['Device Dislodged or Dislocated', 'High Captu...     Unknown
# ...                                                  ...         ...
# 47501                       ['Insufficient Information']       Other
# 47502                       ['Insufficient Information']     Unknown
# 47503                       ['Insufficient Information']       Other
# 47504                                       ['Degraded']       Other
# 47505            ['Device Appears to Trigger Rejection']       Other
#
# [47506 rows x 5 columns]

# %%
eda_proportion(maude_lf, 'defect_type')
# Out:
#                     defect_type  count  percentage
# 0                       Unknown  43885       59.25
# 1                         Other  22544       30.44
# 2               Sensor/Accuracy   3359        4.53
# 3         Mechanical/Structural   1857        2.51
# 4            Functional Failure   1092        1.47
# 5              Electrical/Power    615        0.83
# 6             User/Human Factor    273        0.37
# 7       Sterility/Contamination    163        0.22
# 8            Software/Interface     99        0.13
# 9    Communication/Connectivity     77        0.10
# 10  Environmental/Compatibility     71        0.10
# 11                  Alarm/Alert     25        0.03
# 12           Labeling/Packaging     10        0.01
# 13                         None      1        0.00

# %%
eda_proportion(maude_lf.filter(pl.col('defect_type').eq('Other')), 'defect_confirmed')

# %% [markdown]
# ## vLLM 버전의 주요 개선사항
#
# ### 1. 성능 향상
# - **배치 추론**: vLLM의 네이티브 배치 처리로 처리 속도 대폭 향상
# - **PagedAttention**: 메모리 효율적인 attention 메커니즘
# - **Continuous Batching**: 동적 배치 스케줄링으로 처리량 최적화
#
# ### 2. GPU 활용 최적화
# - Tensor Parallelism 지원 (다중 GPU)
# - 높은 GPU 메모리 활용률 (기본 0.9)
# - 효율적인 KV 캐시 관리
#
# ### 3. 처리 속도 비교 (예상)
# - **Ollama 버전**: ~1-2 samples/s (CPU 또는 단일 GPU)
# - **vLLM 버전**: ~10-50 samples/s (GPU, 배치 크기에 따라)
# - **속도 향상**: 10-30배 빠름
#
# ### 4. 사용법
# ```python
# # 설치
# # pip install vllm
#
# # 단일 GPU
# extractor = BatchMAUDEExtractor(
#     model_path='Qwen/Qwen2.5-7B-Instruct',
#     tensor_parallel_size=1,
#     batch_size=32
# )
#
# # 다중 GPU (4개 사용)
# extractor = BatchMAUDEExtractor(
#     model_path='meta-llama/Llama-3.1-70B-Instruct',
#     tensor_parallel_size=4,
#     batch_size=64
# )
# ```
#
# ### 5. 추가 최적화 옵션
# - `max_model_len`: 시퀀스 길이 제한 (메모리 절약)
# - `gpu_memory_utilization`: GPU 메모리 사용률 조절
# - `quantization`: 양자화 (AWQ, GPTQ 등) 지원
#
# ### 6. 주의사항
# - Chat 템플릿은 모델에 따라 조정 필요 (Qwen, Llama 등)
# - GPU 메모리가 부족하면 `batch_size` 또는 `max_model_len` 줄이기
# - `tensor_parallel_size`는 사용 가능한 GPU 수와 일치해야 함

# %% [markdown]
# # 프롬프팅 관련 문제 (원본)
# 1. 예외 처리가 없어서 llm 다차원분리에 실패하더라도 그대로 그 행이 빈 채로 넘어감 <- 개선 필요
# 2. 드는 시간이 너무 많이 걸려서 프롬프트를 좀 크기를 단축시켜야 됨.
#     * 실제로는 여기서 더 단축시키기가 힘듦.
# 3. system prompt는 더 길어져도 한번만 들어가기 때문에 부담 없이 길게 할 수 있음
#     * 여기가 주로 만져야 되는 부분(퀄리티 상승을 위해서)

# %% [markdown]
# # vLLM 버전에서의 개선사항
#
# ## 1. 예외 처리 강화 ✓
# - 개별 샘플 실패시에도 다른 샘플은 정상 처리
# - `_success`, `_error`, `_raw_response` 필드로 실패 원인 추적
# - 실패한 항목 자동 재시도 (최대 2회)
#
# ## 2. 처리 시간 대폭 단축 ✓
# - **10-30배 빠른 처리 속도**
# - 배치 추론으로 GPU 효율 극대화
# - 1000개 샘플 기준: Ollama 15-20분 → vLLM 1-2분
#
# ## 3. System Prompt 활용
# - System prompt에 상세한 가이드라인 추가 가능
# - 품질 향상을 위한 예시 및 설명 포함
# - 한 번만 인코딩되므로 성능 영향 최소화
#
# ## 4. 추가 개선사항
# - 실시간 처리 진행률 표시
# - 자동 체크포인트 저장
# - 상세한 통계 정보 제공
# - 메모리 효율적인 처리
